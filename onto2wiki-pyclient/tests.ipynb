# %%
import re
from pprint import pprint

# %%
path = './fuc.ttl'
base = 'http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#'
old_new = dict()
classes = []
with open(path, 'r') as f:
    while line := f.readline():
        pars = re.search(r'(\S+) rdf:type (\S+) ;', line)
        if pars:
            if pars.group(2) != 'owl:Class': raise Exception('Unknown syntaxes')
            if pars.group(1).startswith(':'):
                classes.append(pars.group(1)[1:])
                old_new[pars.group(1)[1:]] = base + pars.group(1)[1:]
            else:
                classes.append(pars.group(1).split('#')[1][:-1])
# Out:
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_производство_(административный_процесс)>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Арбитражно-процессуальное_право_(арбитражный_процесс)>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_управление_в_области_использования,_охраны,_защиты_лесного_фонда_и_воспроизводства_лесов>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Гражданско-процессуальное_право_(гражданский_процесс)>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Имущественные_и_неимущественные_права_авторов_открытий,_изобретений_и_рационализаторских_предложений_и_их_охрана>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Конституционное_(государственное)_право>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Конституционное_(государственное)_право_отдельных_стран>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминалистическая_тактика_(тактика_расследования_преступлений)>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминалистическая_техника_(техника_расследования_преступления)>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Льготы_нетрудоспособным,_престарелым,_семьям,_имеющим_детей>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_и_национальное_право_(вопросы_взаимодействия)>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международные_конгрессы,_конференции,_совещания>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Научные_общества,_конгрессы,_конференции,_симпозиумы_юристов>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Научные_общества,_съезды,_конгрессы,_конференции,_симпозиумы_по_психологии>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Общие_вопросы_конституционного_(государственного)_права>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Опека,_попечительство_и_патронат>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Органы,_осуществляющие_оперативно-розыскную_деятельность>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Охрана_секретов_производства_(ноу-хау)>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Правово__режим_информации,_информационных_систем_и_сетей>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Правовое_положение_крестьянских_(фермерских)__хозяйств>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Правовое_регулирование_лесопользования,_воспроизводства_лесов,_лесоразведения,_охраны_и_защиты_лесов>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Причины_и_условия,_порождающие_преступления>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Производство_по_делам_о_несостоятельности_(банкротстве)>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Производство_по_установлению_фактов,_имеющих_юридическое_значение>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Происхождение,_сущность,_исторические_типы_и_функции_государства_и_права>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Сравнительная_психология._Зоопсихология,_этология>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Субъекты_гражданских_прав_(лица)>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Территориальные_(региональные)_органы_исполнительной_власти>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Уголовно-процессуальное_право_(уголовный_процесс)>
# <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Участники_процесса_(субъекта)>

# %%
# pprint(old_new)
pprint(classes)
# Out:
# ['Уголовно-процессуальное_право_отдельных_стран',
#  'Административное_производство_(административный_процесс)',
#  'Арбитражно-процессуальное_право_(арбитражный_процесс)',
#  'Государственное_управление_в_области_использования,_охраны,_защиты_лесного_фонда_и_воспроизводства_лесов',
#  'Гражданско-процессуальное_право_(гражданский_процесс)',
#  'Имущественные_и_неимущественные_права_авторов_открытий,_изобретений_и_рационализаторских_предложений_и_их_охрана',
#  'Конституционное_(государственное)_право',
#  'Конституционное_(государственное)_право_отдельных_стран',
#  'Криминалистическая_тактика_(тактика_расследования_преступлений)',
#  'Криминалистическая_техника_(техника_расследования_преступления)',
#  'Льготы_нетрудоспособным,_престарелым,_семьям,_имеющим_детей',
#  'Международное_и_национальное_право_(вопросы_взаимодействия)',
#  'Международные_конгрессы,_конференции,_совещания',
#  'Научные_общества,_конгрессы,_конференции,_симпозиумы_юристов',
#  'Научные_общества,_съезды,_конгрессы,_конференции,_симпозиумы_по_психологии',
#  'Общие_вопросы_конституционного_(государственного)_права',
#  'Опека,_попечительство_и_патронат',
#  'Органы,_осуществляющие_оперативно-розыскную_деятельность',
#  'Охрана_секретов_производства_(ноу-хау)',
#  'Правово__режим_информации,_информационных_систем_и_сетей',
#  'Правовое_положение_крестьянских_(фермерских)__хозяйств',
#  'Правовое_регулирование_лесопользования,_воспроизводства_лесов,_лесоразведения,_охраны_и_защиты_лесов',
#  'Причины_и_условия,_порождающие_преступления',
#  'Производство_по_делам_о_несостоятельности_(банкротстве)',
#  'Производство_по_установлению_фактов,_имеющих_юридическое_значение',
#  'Происхождение,_сущность,_исторические_типы_и_функции_государства_и_права',
#  'Сравнительная_психология._Зоопсихология,_этология',
#  'Субъекты_гражданских_прав_(лица)',
#  'Территориальные_(региональные)_органы_исполнительной_власти',
#  'Уголовно-процессуальное_право_(уголовный_процесс)',
#  'Участники_процесса_(субъекта)',
#  'Авиационная_и_космическая_психология',
#  'Авторские_договоры',
#  'Авторское_право',
#  'Авторское_право_и_смежные_права',
#  'Авторское_право_и_смежные_права_в_отдельных_странах',
#  'Аграрное_право',
#  'Аграрное_право_отдельных_стран',
#  'Адвокатура',
#  'Административно-правовая_ответственность',
#  'Административное_право',
#  'Административное_право_отдельных_стран',
#  'Антимонопольное_законодательство',
#  'Арбитражно-процессуальное_право_отдельных_стран',
#  'Банковское_законодательство',
#  'Банкротство',
#  'Биологическое_и_социальное_в_психике',
#  'Брак._Семья',
#  'Бюджетное_право',
#  'Виды_преступности',
#  'Виктимология',
#  'Внешняя_политика_и_дипломатия',
#  'Внутригосударственные_органы_внешних_сношений',
#  'Водное_право',
#  'Водное_право_отдельных_стран',
#  'Военная_психология',
#  'Воздухоохранное_право',
#  'Вопросы_трудовых_правоотношений',
#  'Всеобщая_история_государства_и_права',
#  'Всеобщая_история_политических_и_правовых_учений',
#  'Гарантии_и_компенсации',
#  'Государственная_служба',
#  'Государственное_регулирование_и_управление_в_административно-политической_сфере',
#  'Государственное_регулирование_и_управление_в_социально-культурной_сфере',
#  'Государственное_регулирование_и_управление_в_сфере_экономики',
#  'Государственное_регулирование_отношений_недропользования',
#  'Государственное_регулирование_предпринимательской_деятельности',
#  'Государственное_регулирование_сельского_хозяйства',
#  'Государственное_социальное_страхование',
#  'Государственное_управление_в_области_использования_и_охраны_водных_объектов',
#  'Государственное_управление_в_сфере_обороны',
#  'Государственное_устройство',
#  'Государственный_суверенитет',
#  'Государство_и_право._Юридические_науки',
#  'Государство_и_право_отдельных_стран',
#  'Гражданско-правовая_ответственность',
#  'Гражданско-процессуальное_право_отдельных_стран',
#  'Гражданское_право',
#  'Гражданское_право_отдельных_стран',
#  'Детская_и_юношеская_психология',
#  'Деятельность_контрольных_органов',
#  'Дифференциальная_психология',
#  'Доказательства',
#  'Доказательства_в_арбитражном_процессе',
#  'Доказательства_в_уголовном_процессе',
#  'Другие_виды_вещных_прав',
#  'Другие_виды_прикладной_психологии',
#  'Забастовки._Локауты',
#  'Законодательный_процесс',
#  'Законодательство_о_животном_мире',
#  'Законодательство_о_недрах',
#  'Законодательство_о_недрах_отдельных_стран',
#  'Заработная_плата',
#  'Зарубежные_органы_внешних_сношений',
#  'Защита_коммерческой_тайны',
#  'Земельное_право',
#  'Земельное_право_отдельных_стран',
#  'Землеустройство_и_землеустроительный_процесс._Земельный_кадастр',
#  'Избирательное_право._Избирательные_системы._Выборы_и_референдумы',
#  'Имущественные_права_авторов_и_исполнителей',
#  'Инженерная_психология',
#  'Информационная_деятельность_в_области_психологии',
#  'Информационная_деятельность_в_юридических_науках._Правовая_информация',
#  'Информационное_право',
#  'Иск',
#  'Исполнение_судебных_актов',
#  'Использование_произведений_без_согласия_авторов_и_исполнителей',
#  'Историческая_психология',
#  'История_государства_и_права',
#  'История_государства_и_права_отдельных_стран',
#  'История_международного_права',
#  'История_политических_и_правовых_учений',
#  'История_политических_и_правовых_учений_отдельных_стран',
#  'История_психологии._Персоналия',
#  'История_юридической_науки._Персоналия',
#  'Источники_международного_права',
#  'Источники_права',
#  'Кадры_в_области_права_и_юридических_наук',
#  'Кадры_психологов',
#  'Коллективный_договор',
#  'Конституции_и_акты_конституционного_характера',
#  'Криминалистика',
#  'Криминалистика_в_отдельных_странах',
#  'Криминалистическая_экспертиза',
#  'Криминология',
#  'Криминология_в_отдельных_странах',
#  'Лесное_право',
#  'Лесное_право_отдельных_стран',
#  'Личность_преступника',
#  'Личные_неимущественные_права_авторов_и_исполнителей',
#  'Логика_права',
#  'Льготы_ветеранам_войны',
#  'Льготы_для_совмещающих_работу_с_обучением',
#  'Массовые_формы_внеколлективного_поведения',
#  'Материальная_ответственность_рабочих_и_служащих',
#  'Материально-бытовое_обслуживание_нетрудоспособных',
#  'Медицинская_психология',
#  'Международное_воздушное_право',
#  'Международное_гуманитарное_право._Право_вооруженных_конфликтов',
#  'Международное_космическое_право',
#  'Международное_морское_право',
#  'Международное_право',
#  'Международное_право_в_практике_отдельных_государств',
#  'Международное_право_окружающей_среды',
#  'Международное_сотрудничество_в_области_права',
#  'Международное_сотрудничество_в_области_психологии',
#  'Международное_сотрудничество_по_специальным_вопросам',
#  'Международное_уголовное_право',
#  'Международное_частное_право',
#  'Международное_частное_право_в_практике_отдельных_стран',
#  'Международное_экономическое_право',
#  'Международный_гражданский_процесс',
#  'Меры_процессуального_принуждения',
#  'Места_лишения_свободы',
#  'Методика_расследования_отдельных_видов_преступлений',
#  'Методология_и_методы_исследования_юридической_науки',
#  'Методы_исследования_и_моделирования_в_области_психологии._Математические_и_кибернетические_методы',
#  'Методы_психологического_исследования._Математическая_психология',
#  'Муниципальное_право',
#  'Надзор_и_контроль_за_соблюдением_законодательства',
#  'Назначение_наказания',
#  'Налоговое_право',
#  'Наследование_по_завещанию',
#  'Наследование_по_закону',
#  'Наследственное_право',
#  'Наследственное_право_в_международном_частном_праве',
#  'Наследственное_право_отдельных_стран',
#  'Нормирование_труда',
#  'Нотариат',
#  'Общая_психология',
#  'Общественное_мнение_и_право._Опинионика',
#  'Общественные_фонды_содержания_и_обслуживания_детей_в_детских_учреждениях',
#  'Общие_вопросы',
#  'Общие_вопросы_авторского_и_смежных_прав',
#  'Общие_вопросы_аграрного_права',
#  'Общие_вопросы_административного_права',
#  'Общие_вопросы_арбитражного_процесса',
#  'Общие_вопросы_водного_права',
#  'Общие_вопросы_воздухоохранного_права',
#  'Общие_вопросы_гражданского_права',
#  'Общие_вопросы_гражданского_процесса',
#  'Общие_вопросы_законодательства_о_животных',
#  'Общие_вопросы_законодательства_о_недрах',
#  'Общие_вопросы_законодательства_о_правоохранительных_органах',
#  'Общие_вопросы_законодательства_о_социальном_обеспечении',
#  'Общие_вопросы_земельного_права',
#  'Общие_вопросы_информационного_права',
#  'Общие_вопросы_истории_государства_и_права',
#  'Общие_вопросы_истории_политических_и_правовых_учений',
#  'Общие_вопросы_криминалистики',
#  'Общие_вопросы_криминологии',
#  'Общие_вопросы_лесного_права',
#  'Общие_вопросы_международного_права',
#  'Общие_вопросы_международного_частного_права',
#  'Общие_вопросы_наследственного_права',
#  'Общие_вопросы_патентного_права',
#  'Общие_вопросы_предпринимательского_права',
#  'Общие_вопросы_психологии',
#  'Общие_вопросы_семейного_права',
#  'Общие_вопросы_судебной_статистики',
#  'Общие_вопросы_теории_государства_и_права',
#  'Общие_вопросы_трудового_права',
#  'Общие_вопросы_уголовного_права',
#  'Общие_вопросы_уголовного_процесса',
#  'Общие_вопросы_финансового_права',
#  'Общие_вопросы_экологического_права',
#  'Общие_положения_муниципального_права',
#  'Объекты_авторского_и_смежных_прав',
#  'Объекты_гражданских_прав',
#  'Объекты_правовой_охраны_природы',
#  'Объекты_промышленной_собственности._Условия_патентоспособности',
#  'Обязательственное_право',
#  'Обязательственное_право_в_международном_частном_праве',
#  'Организация_научно-исследовательской_работы_в_области_психологии',
#  'Организация_научно-исследовательской_работы_и_общественно-политической_деятельности_юристов',
#  'Организация_труда._Повышение_квалификации',
#  'Органы_административной_юстиции',
#  'Органы_исполнительной_власти',
#  'Органы_местного_самоуправления',
#  'Освобождение_от_уголовной_ответственности_и_наказания',
#  'Основания_возникновения_гражданских_прав_и_обязанностей',
#  'Особенности_производства_по_отдельным_категориям_гражданских_дел',
#  'Особенности_производства_по_отдельным_категориям_уголовных_дел',
#  'Особые_состояния_и_явления_психики',
#  'Осуществление_и_защита_гражданских_прав',
#  'Ответственность_в_авторском_праве',
#  'Ответственность_в_аграрном_праве',
#  'Ответственность_в_земельном_праве',
#  'Ответственность_в_патентном_праве_и_праве_промышленной_собственности',
#  'Ответственность_в_предпринимательском_праве._Споры_в_предпринимательской_деятельности_и_порядок_их_разрешения',
#  'Ответственность_в_семейном_праве',
#  'Ответственность_в_системе_муниципального_права',
#  'Ответственность_за_нарушение_водного_законодательства',
#  'Ответственность_за_нарушение_воздухоохранного_законодательства',
#  'Ответственность_за_нарушение_законодательства_о_животном_мире',
#  'Ответственность_за_нарушение_законодательства_о_наследовании',
#  'Ответственность_за_нарушение_законодательства_о_недрах',
#  'Ответственность_за_нарушение_законодательства_по_социальному_обеспечению',
#  'Ответственность_за_нарушение_лесного_законодательства',
#  'Ответственность_за_нарушение_финансового_законодательства',
#  'Ответственность_по_конституционному_праву',
#  'Отдельные_виды_преступлений',
#  'Отклоняющееся_поведение',
#  'Открытие_наследства_и_меры_его_охраны',
#  'Отраслевые_и_межотраслевые_органы_исполнительной_власти',
#  'Охрана_авторских_прав',
#  'Охрана_водных_объектов',
#  'Охрана_земли',
#  'Охрана_недр',
#  'Охрана_труда',
#  'Партийная_система._Общественные_организации',
#  'Патентное_право',
#  'Патентное_право._Право_промышленной_собственности',
#  'Патентное_право_и_право_промышленной_собственности_отдельных_стран',
#  'Патенты_и_их_правовая_защита',
#  'Патопсихология',
#  'Педагогическая_психология',
#  'Пенитенциарные_системы._Режим_содержания_заключенных._Управление_местами_лишения_свободы',
#  'Пенсии',
#  'Переход_наследства_к_государству',
#  'Планирование_и_прогнозирование_в_праве',
#  'Плата_при_пользовании_недрами',
#  'Платежи_за_пользование_лесным_фондом',
#  'Платность_водопользования',
#  'Подведомственность_и_подсудность',
#  'Подведомственность_и_подсудность_в_арбитражном_процессе',
#  'Подсудность',
#  'Политический_режим',
#  'Понятие_наследства',
#  'Пособия',
#  'Права_и_свободы_человека_и_гражданина',
#  'Права_патентообладателей',
#  'Права_человека',
#  'Право_водопользования._Целевое_использование_водных_объектов',
#  'Право_землепользования_и_его_виды',
#  'Право_и_естественные_науки',
#  'Право_и_научно-технический_прогресс',
#  'Право_и_политика',
#  'Право_международной_безопасности',
#  'Право_международных_договоров',
#  'Право_международных_организаций',
#  'Право_мирного_разрешения_споров',
#  'Право_на_изобретение',
#  'Право_на_информацию',
#  'Право_на_научное_открытие',
#  'Право_на_научное_открытие_в_патентном_праве',
#  'Право_на_рационализаторское_предложение',
#  'Право_пользования_недрами',
#  'Право_собственности',
#  'Право_собственности_в_международном_частном_праве',
#  'Право_собственности_и_другие_права_на_водные_объекты',
#  'Право_собственности_на_землю',
#  'Право_собственности_на_лесной_фонд',
#  'Право_собственности_на_недра',
#  'Право_собственности_на_объекты_животного_мира',
#  'Право_собственности_на_природные_ресурсы',
#  'Право_социального_обеспечения',
#  'Право_социального_обеспечения_в_отдельных_странах',
#  'Правовая_охрана_атмосферного_воздуха',
#  'Правовая_охрана_объектов_животного_мира',
#  'Правовая_работа_и_правовое_обслуживание',
#  'Правовое_оформление_права_наследования',
#  'Правовое_положение_сельскохозяйственных_организаций',
#  'Правовое_регулирование_ведения_государственных_кадастров_природных_ресурсов_и_объектов',
#  'Правовое_регулирование_государственного_управления_земельными_ресурсами',
#  'Правовое_регулирование_государственного_управления_природопользованием_и_охраной_окружающей_среды',
#  'Правовое_регулирование_государственных_доходов._Налоговое_законодательство',
#  'Правовое_регулирование_государственных_расходов_и_бюджетного_финансирования',
#  'Правовое_регулирование_информационной_безопасности',
#  'Правовое_регулирование_использования_объектов_животного_мира',
#  'Правовое_регулирование_личного_подсобного_хозяйства_граждан',
#  'Правовое_регулирование_международного_обмена_информацией_и_использования_глобальных_информационных_сетей',
#  'Правовое_регулирование_отдельных_отраслей_экономики',
#  'Правовое_регулирование_оценки_воздействия_на_окружающую_среду_и_экологической_экспертизы',
#  'Правовое_регулирование_сельскохозяйственной_кооперации',
#  'Правовое_регулирование_средств_массовой_информации',
#  'Правовое_регулирование_цен__и_тарифов',
#  'Правовое_регулирование_экологического_воспитания_и_образования',
#  'Правовое_регулирование_экологического_лицензирования',
#  'Правовое_регулирование_экологического_нормирования',
#  'Правовое_регулирование_экологической_сертификации',
#  'Правовое_регулирование_экономического_механизма_природопользования_и_охраны_окружающей_среды',
#  'Правовой_режим_земель_водного_фонда',
#  'Правовой_режим_земель_лесного_фонда',
#  'Правовой_режим_земель_несельскохозяйственного_назначения',
#  'Правовой_режим_земель_сельскохозяйственного_назначения',
#  'Правовой_режим_информационных_ресурсов',
#  'Правовой_режим_населенных_пунктов',
#  'Правовой_режим_особо_охраняемых_природных_территорий',
#  'Правовой_режим_экологически_неблагополучных_территорий',
#  'Правовые_аспекты_ирригации_и_мелиорации',
#  'Правовые_основы_инвестиционной_деятельности',
#  'Правовые_основы_расчетов_и_денежного_обращения._Основы_валютного_законодательства',
#  'Правовые_проблемы_охраны_окружающей_среды._Экологическое_право',
#  'Правовые_формы_предпринимательской_деятельности',
#  'Правонарушения_в_области_информатики._Ответственность_в_информационном_праве',
#  'Правоохранительные_органы',
#  'Правоохранительные_органы_отдельных_стран',
#  'Практическая_психология',
#  'Предметы_ведения_и_полномочия_органов_исполнительной_власти',
#  'Предпринимательское_право',
#  'Предпринимательское_право_отдельных_стран',
#  'Представительство',
#  'Представительство_в_арбитражном_суде',
#  'Представительство_в_международном_частном_праве',
#  'Предупреждение_преступлений',
#  'Преподавание_юридических_наук',
#  'Преступность_и_явления_социальной_патологии',
#  'Прикладная_психология',
#  'Принципы_международного_права',
#  'Принятие_наследства_и_отказ_от_наследства',
#  'Прогнозирование_преступности',
#  'Производство_по_разрешению_экономических_споров',
#  'Прокуратура',
#  'Пропаганда_правовых_знаний',
#  'Процессуальные__сроки_и_судебные_расходы_в_уголовном_процессе',
#  'Процессуальные_акты_и_действия',
#  'Процессуальные_акты_и_действия_в_уголовном_процессе',
#  'Процессуальные_сроки_и_судебные_расходы',
#  'Процессуальные_сроки_и_судебные_расходы_в_арбитражном_процессе',
#  'Процессы_социализации',
#  'Психика_и_сознание',
#  'Психические_процессы_и_состояния',
#  'Психология',
#  'Психология_деятельности_и_поведения._Психология_мотивации',
#  'Психология_зрелости',
#  'Психология_классов_и_крупных_социальных_общностей',
#  'Психология_личности',
#  'Психология_малых_групп_и_коллективов',
#  'Психология_межличностных_отношений',
#  'Психология_общения._Процессы_коммуникации',
#  'Психология_пола',
#  'Психология_права',
#  'Психология_развития._Возрастная_психология._Сравнительная_психология',
#  'Психология_семьи_и_быта',
#  'Психология_спорта',
#  'Психология_старения',
#  'Психология_творчества',
#  'Психология_труда',
#  'Психология_управления',
#  'Психология_чтения_и_библиотечной_работы',
#  'Психофизиология',
#  'Рабочее_время_и_время_отдыха',
#  'Развитие_психики',
#  'Родство_по_семейному_праву',
#  'Розыск',
#  'Роль_профессиональных_союзов_в_трудовых_правоотношениях._Участие_рабочих_и_служащих_в_управлении_производством',
#  'Сделки',
#  'Семейное_право',
#  'Семейное_право_в_международном_частном_праве',
#  'Семейное_право_отдельных_стран',
#  'Символы_государства',
#  'Система_органов_государственной_власти',
#  'Служащие_мест_лишения_свободы',
#  'Современное_состояние_и_перспективы_развития_психологии',
#  'Современное_состояние_и_перспективы_развития_юридической_науки',
#  'Состояние_преступности',
#  'Социальная_психология',
#  'Социальная_психология_личности._Личность_и_общество._Психология_жизненной_сферы',
#  'Социальные_нормы_и_ценности',
#  'Социология_права',
#  'Социология_преступности',
#  'Стадии_арбитражного_процесса',
#  'Стадии_гражданского_процесса',
#  'Стадии_уголовного_процесса',
#  'Ступени_исполнения_приговора',
#  'Субъективные_гражданские_права',
#  'Субъекты_авторского_и_смежных_прав',
#  'Субъекты_гражданских_процессуальных_отношений',
#  'Субъекты_международного_права',
#  'Субъекты_международного_частного_права',
#  'Субъекты_предпринимательского_права',
#  'Суд._Судоустройство',
#  'Судебная_статистика',
#  'Судебная_статистика_отдельных_стран',
#  'Судебная_статистика_по_гражданским_делам',
#  'Судебная_статистика_по_уголовным_делам',
#  'Судебные_акты',
#  'Теория_государства',
#  'Теория_государства_и_права',
#  'Теория_международного_права',
#  'Теория_права',
#  'Терминология._Справочная_литература._Учебная_литература',
#  'Территория_в_международном_праве',
#  'Труд_женщин',
#  'Труд_молодежи',
#  'Трудовая_дисциплина',
#  'Трудовое_право',
#  'Трудовое_право_отдельных_стран',
#  'Трудовой_договор',
#  'Трудовой_стаж',
#  'Трудовые_ресурсы._Трудоустройство',
#  'Трудовые_споры',
#  'Уголовно-исполнительное_право._Пенитенциария',
#  'Уголовное_право',
#  'Уголовное_право_отдельных_стран',
#  'Унифицированные_нормы_в_международном_частном_праве',
#  'Управление_и_организация_в_области_социального_обеспечения',
#  'Управление_использованием_и_охраной_животного_мира',
#  'Управление_охраной_атмосферного_воздуха',
#  'Усыновление',
#  'Участие_общественности_в_деятельности_правоохранительных_органов',
#  'Участники_арбитражного_процесса',
#  'Учение_о_наказании',
#  'Учение_о_преступлении',
#  'Учении_о_коллизии_законов',
#  'Философские_вопросы_и_методология_психологии',
#  'Философския_права',
#  'Финансовая_деятельность_государства._Финансовый_контроль',
#  'Финансово-экономическая_основа_местного_самоуправления',
#  'Финансовое_право',
#  'Финансовое_право_отдельных_стран',
#  'Фонды_социального_обеспечения_и_социального_страхования',
#  'Формы_и_методы_борьбы_с_преступностью_и_предупреждения_преступлений',
#  'Формы_и_методы_управления',
#  'Формы_прямого_волеизъявления_граждан_и_другие_формы_осуществления_местного_самоуправления',
#  'Экологические_права_человека_и_гражданина',
#  'Экологический_аудит._Экологический_мониторинг._Экологический_контроль',
#  'Экологическое_право_в_отдельных_странах',
#  'Экономическая_психология',
#  'Этнопсихология',
#  'Юридическая_ответственность_за_экологические_правонарушения',
#  'Юридическая_психология',
#  'Юридическая_терминология']

# %%
new_file = []
with open(path, 'r') as f:
    while line := f.readline():
        pars_class = re.search(r'(\S+) rdf:type (\S+) ;', line)
        parse_subclass = re.search(r'rdfs:subClassOf :(\S+)', line[:-2])
        if pars_class:
            if pars_class.group(2) != 'owl:Class': raise Exception('Unknown syntaxes')
            if pars_class.group(1).startswith(':'):
                line = line.replace(pars_class.group(1), '<' + old_new[pars_class.group(1)[1:]] + '>')
        elif parse_subclass and parse_subclass.group(1) in old_new:
            line = line.replace(parse_subclass.group(1), '<' + old_new[parse_subclass.group(1)] + '>')
        new_file.append(line)

# %%
new_file
# Out:
# ['@prefix : <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/> .\n',
#  '@prefix owl: <http://www.w3.org/2002/07/owl#> .\n',
#  '@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .\n',
#  '@prefix xml: <http://www.w3.org/XML/1998/namespace> .\n',
#  '@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n',
#  '@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n',
#  '@base <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/> .\n',
#  '\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19> rdf:type owl:Ontology .\n',
#  '\n',
#  '#################################################################\n',
#  '#    Classes\n',
#  '#################################################################\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Уголовно-процессуальное_право_отдельных_стран\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Уголовно-процессуальное_право_отдельных_стран> rdf:type owl:Class ;\n',
#  '                                               rdfs:subClassOf <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Уголовно-процессуальное_право_(уголовный_процесс)> ;\n',
#  '                                               rdfs:label "Уголовно-процессуальное право отдельных стран"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_производство_(административный_процесс)\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_производство_(административный_процесс)> rdf:type owl:Class ;\n',
#  '                                                                                                                                       rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_право> ;\n',
#  '                                                                                                                                       rdfs:label "Административное производство (административный процесс)"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Арбитражно-процессуальное_право_(арбитражный_процесс)\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Арбитражно-процессуальное_право_(арбитражный_процесс)> rdf:type owl:Class ;\n',
#  '                                                                                                                                    rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '                                                                                                                                    rdfs:label "Арбитражно-процессуальное право (арбитражный процесс)"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_управление_в_области_использования,_охраны,_защиты_лесного_фонда_и_воспроизводства_лесов\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_управление_в_области_использования,_охраны,_защиты_лесного_фонда_и_воспроизводства_лесов> rdf:type owl:Class ;\n',
#  '                                                                                                                                                                                       rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Лесное_право> ;\n',
#  '                                                                                                                                                                                       rdfs:label "Государственное управление в области использования, охраны, защиты лесного фонда и воспроизводства лесов"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Гражданско-процессуальное_право_(гражданский_процесс)\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Гражданско-процессуальное_право_(гражданский_процесс)> rdf:type owl:Class ;\n',
#  '                                                                                                                                    rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '                                                                                                                                    rdfs:label "Гражданско-процессуальное право (гражданский процесс)"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Имущественные_и_неимущественные_права_авторов_открытий,_изобретений_и_рационализаторских_предложений_и_их_охрана\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Имущественные_и_неимущественные_права_авторов_открытий,_изобретений_и_рационализаторских_предложений_и_их_охрана> rdf:type owl:Class ;\n',
#  '                                                                                                                                                                                               rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Патентное_право._Право_промышленной_собственности> ;\n',
#  '                                                                                                                                                                                               rdfs:label "Имущественные и неимущественные права авторов открытий, изобретений и рационализаторских предложений и их охрана"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Конституционное_(государственное)_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Конституционное_(государственное)_право> rdf:type owl:Class ;\n',
#  '                                                                                                                      rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '                                                                                                                      rdfs:label "Конституционное (государственное) право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Конституционное_(государственное)_право_отдельных_стран\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Конституционное_(государственное)_право_отдельных_стран> rdf:type owl:Class ;\n',
#  '                                                                                                                                      rdfs:subClassOf <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Конституционное_(государственное)_право> ;\n',
#  '                                                                                                                                      rdfs:label "Конституционное (государственное) право отдельных стран"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминалистическая_тактика_(тактика_расследования_преступлений)\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминалистическая_тактика_(тактика_расследования_преступлений)> rdf:type owl:Class ;\n',
#  '                                                                                                                                              rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминалистика> ;\n',
#  '                                                                                                                                              rdfs:label "Криминалистическая тактика (тактика расследования преступлений)"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминалистическая_техника_(техника_расследования_преступления)\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминалистическая_техника_(техника_расследования_преступления)> rdf:type owl:Class ;\n',
#  '                                                                                                                                              rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминалистика> ;\n',
#  '                                                                                                                                              rdfs:label "Криминалистическая техника (техника расследования преступления)"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Льготы_нетрудоспособным,_престарелым,_семьям,_имеющим_детей\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Льготы_нетрудоспособным,_престарелым,_семьям,_имеющим_детей> rdf:type owl:Class ;\n',
#  '                                                                                                                                          rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Право_социального_обеспечения> ;\n',
#  '                                                                                                                                          rdfs:label "Льготы нетрудоспособным, престарелым, семьям, имеющим детей"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_и_национальное_право_(вопросы_взаимодействия)\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_и_национальное_право_(вопросы_взаимодействия)> rdf:type owl:Class ;\n',
#  '                                                                                                                                          rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                                                                                                                                          rdfs:label "Международное и национальное право (вопросы взаимодействия)"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международные_конгрессы,_конференции,_совещания\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международные_конгрессы,_конференции,_совещания> rdf:type owl:Class ;\n',
#  '                                                                                                                              rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                                                                                                                              rdfs:label "Международные конгрессы, конференции, совещания"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Научные_общества,_конгрессы,_конференции,_симпозиумы_юристов\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Научные_общества,_конгрессы,_конференции,_симпозиумы_юристов> rdf:type owl:Class ;\n',
#  '                                                                                                                                           rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Общие_вопросы> ;\n',
#  '                                                                                                                                           rdfs:label "Научные общества, конгрессы, конференции, симпозиумы юристов"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Научные_общества,_съезды,_конгрессы,_конференции,_симпозиумы_по_психологии\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Научные_общества,_съезды,_конгрессы,_конференции,_симпозиумы_по_психологии> rdf:type owl:Class ;\n',
#  '                                                                                                                                                         rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Общие_вопросы_психологии> ;\n',
#  '                                                                                                                                                         rdfs:label "Научные общества, съезды, конгрессы, конференции, симпозиумы по психологии"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Общие_вопросы_конституционного_(государственного)_права\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Общие_вопросы_конституционного_(государственного)_права> rdf:type owl:Class ;\n',
#  '                                                                                                                                      rdfs:subClassOf <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Конституционное_(государственное)_право> ;\n',
#  '                                                                                                                                      rdfs:label "Общие вопросы конституционного (государственного) права"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Опека,_попечительство_и_патронат\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Опека,_попечительство_и_патронат> rdf:type owl:Class ;\n',
#  '                                                                                                               rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Семейное_право> ;\n',
#  '                                                                                                               rdfs:label "Опека, попечительство и патронат"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Органы,_осуществляющие_оперативно-розыскную_деятельность\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Органы,_осуществляющие_оперативно-розыскную_деятельность> rdf:type owl:Class ;\n',
#  '                                                                                                                                       rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Правоохранительные_органы> ;\n',
#  '                                                                                                                                       rdfs:label "Органы, осуществляющие оперативно-розыскную деятельность"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Охрана_секретов_производства_(ноу-хау)\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Охрана_секретов_производства_(ноу-хау)> rdf:type owl:Class ;\n',
#  '                                                                                                                     rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Патентное_право._Право_промышленной_собственности> ;\n',
#  '                                                                                                                     rdfs:label "Охрана секретов производства (ноу-хау)"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Правово__режим_информации,_информационных_систем_и_сетей\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Правово__режим_информации,_информационных_систем_и_сетей> rdf:type owl:Class ;\n',
#  '                                                                                                                                       rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Информационное_право> ;\n',
#  '                                                                                                                                       rdfs:label "Правовой режим информации, информационных систем и сетей"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Правовое_положение_крестьянских_(фермерских)__хозяйств\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Правовое_положение_крестьянских_(фермерских)__хозяйств> rdf:type owl:Class ;\n',
#  '                                                                                                                                     rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Аграрное_право> ;\n',
#  '                                                                                                                                     rdfs:label "Правовое положение крестьянских (фермерских) хозяйств"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Правовое_регулирование_лесопользования,_воспроизводства_лесов,_лесоразведения,_охраны_и_защиты_лесов\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Правовое_регулирование_лесопользования,_воспроизводства_лесов,_лесоразведения,_охраны_и_защиты_лесов> rdf:type owl:Class ;\n',
#  '                                                                                                                                                                                   rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Лесное_право> ;\n',
#  '                                                                                                                                                                                   rdfs:label "Правовое регулирование лесопользования, воспроизводства лесов, лесоразведения, охраны и защиты лесов"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Причины_и_условия,_порождающие_преступления\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Причины_и_условия,_порождающие_преступления> rdf:type owl:Class ;\n',
#  '                                                                                                                          rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминология> ;\n',
#  '                                                                                                                          rdfs:label "Причины и условия, порождающие преступления"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Производство_по_делам_о_несостоятельности_(банкротстве)\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Производство_по_делам_о_несостоятельности_(банкротстве)> rdf:type owl:Class ;\n',
#  '                                                                                                                                      rdfs:subClassOf <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Арбитражно-процессуальное_право_(арбитражный_процесс)> ;\n',
#  '                                                                                                                                      rdfs:label "Производство по делам о несостоятельности (банкротстве)"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Производство_по_установлению_фактов,_имеющих_юридическое_значение\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Производство_по_установлению_фактов,_имеющих_юридическое_значение> rdf:type owl:Class ;\n',
#  '                                                                                                                                                rdfs:subClassOf <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Арбитражно-процессуальное_право_(арбитражный_процесс)> ;\n',
#  '                                                                                                                                                rdfs:label "Производство по установлению фактов, имеющих юридическое значение"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Происхождение,_сущность,_исторические_типы_и_функции_государства_и_права\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Происхождение,_сущность,_исторические_типы_и_функции_государства_и_права> rdf:type owl:Class ;\n',
#  '                                                                                                                                                       rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Теория_государства_и_права> ;\n',
#  '                                                                                                                                                       rdfs:label "Происхождение, сущность, исторические типы и функции государства и права"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Сравнительная_психология._Зоопсихология,_этология\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Сравнительная_психология._Зоопсихология,_этология> rdf:type owl:Class ;\n',
#  '                                                                                                                                rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Психология_развития._Возрастная_психология._Сравнительная_психология> ;\n',
#  '                                                                                                                                rdfs:label "Сравнительная психология. Зоопсихология, этология"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Субъекты_гражданских_прав_(лица)\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Субъекты_гражданских_прав_(лица)> rdf:type owl:Class ;\n',
#  '                                                                                                               rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Гражданское_право> ;\n',
#  '                                                                                                               rdfs:label "Субъекты гражданских прав (лица)"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Территориальные_(региональные)_органы_исполнительной_власти\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Территориальные_(региональные)_органы_исполнительной_власти> rdf:type owl:Class ;\n',
#  '                                                                                                                                          rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_право> ;\n',
#  '                                                                                                                                          rdfs:label "Территориальные (региональные) органы исполнительной власти"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Уголовно-процессуальное_право_(уголовный_процесс)\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Уголовно-процессуальное_право_(уголовный_процесс)> rdf:type owl:Class ;\n',
#  '                                                                                                                                rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '                                                                                                                                rdfs:label "Уголовно-процессуальное право (уголовный процесс)"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Участники_процесса_(субъекта)\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Участники_процесса_(субъекта)> rdf:type owl:Class ;\n',
#  '                                                                                                            rdfs:subClassOf <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Уголовно-процессуальное_право_(уголовный_процесс)> ;\n',
#  '                                                                                                            rdfs:label "Участники процесса (субъекта)"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Авиационная_и_космическая_психология\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Авиационная_и_космическая_психология> rdf:type owl:Class ;\n',
#  '                                      rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Прикладная_психология> ;\n',
#  '                                      rdfs:label "Авиационная и космическая психология"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Авторские_договоры\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Авторские_договоры> rdf:type owl:Class ;\n',
#  '                    rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Авторское_право_и_смежные_права> ;\n',
#  '                    rdfs:label "Авторские договоры"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Авторское_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Авторское_право> rdf:type owl:Class ;\n',
#  '                 rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_частное_право> ;\n',
#  '                 rdfs:label "Авторское право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Авторское_право_и_смежные_права\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Авторское_право_и_смежные_права> rdf:type owl:Class ;\n',
#  '                                 rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '                                 rdfs:label "Авторское право и смежные права"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Авторское_право_и_смежные_права_в_отдельных_странах\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Авторское_право_и_смежные_права_в_отдельных_странах> rdf:type owl:Class ;\n',
#  '                                                     rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Авторское_право_и_смежные_права> ;\n',
#  '                                                     rdfs:label "Авторское право и смежные права в отдельных странах"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Аграрное_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Аграрное_право> rdf:type owl:Class ;\n',
#  '                rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '                rdfs:label "Аграрное право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Аграрное_право_отдельных_стран\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Аграрное_право_отдельных_стран> rdf:type owl:Class ;\n',
#  '                                rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Аграрное_право> ;\n',
#  '                                rdfs:label "Аграрное право отдельных стран"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Адвокатура\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Адвокатура> rdf:type owl:Class ;\n',
#  '            rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Правоохранительные_органы> ;\n',
#  '            rdfs:label "Адвокатура"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Административно-правовая_ответственность\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административно-правовая_ответственность> rdf:type owl:Class ;\n',
#  '                                          rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_право> ;\n',
#  '                                          rdfs:label "Административно-правовая ответственность"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Административное_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_право> rdf:type owl:Class ;\n',
#  '                        rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '                        rdfs:label "Административное право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Административное_право_отдельных_стран\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_право_отдельных_стран> rdf:type owl:Class ;\n',
#  '                                        rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_право> ;\n',
#  '                                        rdfs:label "Административное право отдельных стран"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Антимонопольное_законодательство\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Антимонопольное_законодательство> rdf:type owl:Class ;\n',
#  '                                  rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Предпринимательское_право> ;\n',
#  '                                  rdfs:label "Антимонопольное законодательство"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Арбитражно-процессуальное_право_отдельных_стран\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Арбитражно-процессуальное_право_отдельных_стран> rdf:type owl:Class ;\n',
#  '                                                 rdfs:subClassOf <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Арбитражно-процессуальное_право_(арбитражный_процесс)> ;\n',
#  '                                                 rdfs:label "Арбитражно-процессуальное право отдельных стран"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Банковское_законодательство\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Банковское_законодательство> rdf:type owl:Class ;\n',
#  '                             rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Финансовое_право> ;\n',
#  '                             rdfs:label "Банковское законодательство"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Банкротство\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Банкротство> rdf:type owl:Class ;\n',
#  '             rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Предпринимательское_право> ;\n',
#  '             rdfs:label "Банкротство"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Биологическое_и_социальное_в_психике\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Биологическое_и_социальное_в_психике> rdf:type owl:Class ;\n',
#  '                                      rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Общая_психология> ;\n',
#  '                                      rdfs:label "Биологическое и социальное в психике"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Брак._Семья\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Брак._Семья> rdf:type owl:Class ;\n',
#  '             rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Семейное_право> ;\n',
#  '             rdfs:label "Брак. Семья"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Бюджетное_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Бюджетное_право> rdf:type owl:Class ;\n',
#  '                 rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Финансовое_право> ;\n',
#  '                 rdfs:label "Бюджетное право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Виды_преступности\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Виды_преступности> rdf:type owl:Class ;\n',
#  '                   rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминология> ;\n',
#  '                   rdfs:label "Виды преступности"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Виктимология\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Виктимология> rdf:type owl:Class ;\n',
#  '              rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминология> ;\n',
#  '              rdfs:label "Виктимология"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Внешняя_политика_и_дипломатия\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Внешняя_политика_и_дипломатия> rdf:type owl:Class ;\n',
#  '                               rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                               rdfs:label "Внешняя политика и дипломатия"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Внутригосударственные_органы_внешних_сношений\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Внутригосударственные_органы_внешних_сношений> rdf:type owl:Class ;\n',
#  '                                               rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                                               rdfs:label "Внутригосударственные органы внешних сношений"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Водное_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Водное_право> rdf:type owl:Class ;\n',
#  '              rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '              rdfs:label "Водное право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Водное_право_отдельных_стран\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Водное_право_отдельных_стран> rdf:type owl:Class ;\n',
#  '                              rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Водное_право> ;\n',
#  '                              rdfs:label "Водное право отдельных стран"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Военная_психология\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Военная_психология> rdf:type owl:Class ;\n',
#  '                    rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Прикладная_психология> ;\n',
#  '                    rdfs:label "Военная психология"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Воздухоохранное_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Воздухоохранное_право> rdf:type owl:Class ;\n',
#  '                       rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '                       rdfs:label "Воздухоохранное право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Вопросы_трудовых_правоотношений\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Вопросы_трудовых_правоотношений> rdf:type owl:Class ;\n',
#  '                                 rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_частное_право> ;\n',
#  '                                 rdfs:label "Вопросы трудовых правоотношений"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Всеобщая_история_государства_и_права\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Всеобщая_история_государства_и_права> rdf:type owl:Class ;\n',
#  '                                      rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#История_государства_и_права> ;\n',
#  '                                      rdfs:label "Всеобщая история государства и права"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Всеобщая_история_политических_и_правовых_учений\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Всеобщая_история_политических_и_правовых_учений> rdf:type owl:Class ;\n',
#  '                                                 rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#История_политических_и_правовых_учений> ;\n',
#  '                                                 rdfs:label "Всеобщая история политических и правовых учений"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Гарантии_и_компенсации\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Гарантии_и_компенсации> rdf:type owl:Class ;\n',
#  '                        rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Трудовое_право> ;\n',
#  '                        rdfs:label "Гарантии и компенсации"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственная_служба\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственная_служба> rdf:type owl:Class ;\n',
#  '                        rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_право> ;\n',
#  '                        rdfs:label "Государственная служба"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственное_регулирование_и_управление_в_административно-политической_сфере\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_регулирование_и_управление_в_административно-политической_сфере> rdf:type owl:Class ;\n',
#  '                                                                                 rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_право> ;\n',
#  '                                                                                 rdfs:label "Государственное регулирование и управление в административно-политической сфере"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственное_регулирование_и_управление_в_социально-культурной_сфере\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_регулирование_и_управление_в_социально-культурной_сфере> rdf:type owl:Class ;\n',
#  '                                                                         rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_право> ;\n',
#  '                                                                         rdfs:label "Государственное регулирование и управление в социально-культурной сфере"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственное_регулирование_и_управление_в_сфере_экономики\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_регулирование_и_управление_в_сфере_экономики> rdf:type owl:Class ;\n',
#  '                                                              rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_право> ;\n',
#  '                                                              rdfs:label "Государственное регулирование и управление в сфере экономики"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственное_регулирование_отношений_недропользования\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_регулирование_отношений_недропользования> rdf:type owl:Class ;\n',
#  '                                                          rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Законодательство_о_недрах> ;\n',
#  '                                                          rdfs:label "Государственное регулирование отношений недропользования"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственное_регулирование_предпринимательской_деятельности\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_регулирование_предпринимательской_деятельности> rdf:type owl:Class ;\n',
#  '                                                                rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Предпринимательское_право> ;\n',
#  '                                                                rdfs:label "Государственное регулирование предпринимательской деятельности"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственное_регулирование_сельского_хозяйства\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_регулирование_сельского_хозяйства> rdf:type owl:Class ;\n',
#  '                                                   rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Аграрное_право> ;\n',
#  '                                                   rdfs:label "Государственное регулирование сельского хозяйства"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственное_социальное_страхование\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_социальное_страхование> rdf:type owl:Class ;\n',
#  '                                        rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Трудовое_право> ;\n',
#  '                                        rdfs:label "Государственное социальное страхование"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственное_управление_в_области_использования_и_охраны_водных_объектов\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_управление_в_области_использования_и_охраны_водных_объектов> rdf:type owl:Class ;\n',
#  '                                                                             rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Водное_право> ;\n',
#  '                                                                             rdfs:label "Государственное управление в области использования и охраны водных объектов"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственное_управление_в_сфере_обороны\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_управление_в_сфере_обороны> rdf:type owl:Class ;\n',
#  '                                            rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Административное_право> ;\n',
#  '                                            rdfs:label "Государственное управление в сфере обороны"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственное_устройство\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственное_устройство> rdf:type owl:Class ;\n',
#  '                            rdfs:subClassOf <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Конституционное_(государственное)_право> ;\n',
#  '                            rdfs:label "Государственное устройство"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Государственный_суверенитет\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государственный_суверенитет> rdf:type owl:Class ;\n',
# ...
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Медицинская_психология\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Медицинская_психология> rdf:type owl:Class ;\n',
#  '                        rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Прикладная_психология> ;\n',
#  '                        rdfs:label "Медицинская психология"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_воздушное_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_воздушное_право> rdf:type owl:Class ;\n',
#  '                               rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                               rdfs:label "Международное воздушное право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_гуманитарное_право._Право_вооруженных_конфликтов\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_гуманитарное_право._Право_вооруженных_конфликтов> rdf:type owl:Class ;\n',
#  '                                                                rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                                                                rdfs:label "Международное гуманитарное право. Право вооруженных конфликтов"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_космическое_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_космическое_право> rdf:type owl:Class ;\n',
#  '                                 rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                                 rdfs:label "Международное космическое право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_морское_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_морское_право> rdf:type owl:Class ;\n',
#  '                             rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                             rdfs:label "Международное морское право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> rdf:type owl:Class ;\n',
#  '                     rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '                     rdfs:label "Международное право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_право_в_практике_отдельных_государств\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право_в_практике_отдельных_государств> rdf:type owl:Class ;\n',
#  '                                                     rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                                                     rdfs:label "Международное право в практике отдельных государств"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_право_окружающей_среды\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право_окружающей_среды> rdf:type owl:Class ;\n',
#  '                                      rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                                      rdfs:label "Международное право окружающей среды"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_сотрудничество_в_области_права\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_сотрудничество_в_области_права> rdf:type owl:Class ;\n',
#  '                                              rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Общие_вопросы> ;\n',
#  '                                              rdfs:label "Международное сотрудничество в области права"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_сотрудничество_в_области_психологии\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_сотрудничество_в_области_психологии> rdf:type owl:Class ;\n',
#  '                                                   rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Общие_вопросы_психологии> ;\n',
#  '                                                   rdfs:label "Международное сотрудничество в области психологии"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_сотрудничество_по_специальным_вопросам\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_сотрудничество_по_специальным_вопросам> rdf:type owl:Class ;\n',
#  '                                                      rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                                                      rdfs:label "Международное сотрудничество по специальным вопросам"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_уголовное_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_уголовное_право> rdf:type owl:Class ;\n',
#  '                               rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                               rdfs:label "Международное уголовное право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_частное_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_частное_право> rdf:type owl:Class ;\n',
#  '                             rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '                             rdfs:label "Международное частное право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_частное_право_в_практике_отдельных_стран\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_частное_право_в_практике_отдельных_стран> rdf:type owl:Class ;\n',
#  '                                                        rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_частное_право> ;\n',
#  '                                                        rdfs:label "Международное частное право в практике отдельных стран"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международное_экономическое_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_экономическое_право> rdf:type owl:Class ;\n',
#  '                                   rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_право> ;\n',
#  '                                   rdfs:label "Международное экономическое право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Международный_гражданский_процесс\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международный_гражданский_процесс> rdf:type owl:Class ;\n',
#  '                                   rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Международное_частное_право> ;\n',
#  '                                   rdfs:label "Международный гражданский процесс"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Меры_процессуального_принуждения\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Меры_процессуального_принуждения> rdf:type owl:Class ;\n',
#  '                                  rdfs:subClassOf <http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Уголовно-процессуальное_право_(уголовный_процесс)> ;\n',
#  '                                  rdfs:label "Меры процессуального принуждения"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Места_лишения_свободы\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Места_лишения_свободы> rdf:type owl:Class ;\n',
#  '                       rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Уголовно-исполнительное_право._Пенитенциария> ;\n',
#  '                       rdfs:label "Места лишения свободы"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Методика_расследования_отдельных_видов_преступлений\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Методика_расследования_отдельных_видов_преступлений> rdf:type owl:Class ;\n',
#  '                                                     rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Криминалистика> ;\n',
#  '                                                     rdfs:label "Методика расследования отдельных видов преступлений"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Методология_и_методы_исследования_юридической_науки\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Методология_и_методы_исследования_юридической_науки> rdf:type owl:Class ;\n',
#  '                                                     rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Общие_вопросы> ;\n',
#  '                                                     rdfs:label "Методология и методы исследования юридической науки"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Методы_исследования_и_моделирования_в_области_психологии._Математические_и_кибернетические_методы\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Методы_исследования_и_моделирования_в_области_психологии._Математические_и_кибернетические_методы> rdf:type owl:Class ;\n',
#  '                                                                                                   rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Общие_вопросы_психологии> ;\n',
#  '                                                                                                   rdfs:label "Методы исследования и моделирования в области психологии. Математические и кибернетические методы"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Методы_психологического_исследования._Математическая_психология\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Методы_психологического_исследования._Математическая_психология> rdf:type owl:Class ;\n',
#  '                                                                 rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Общая_психология> ;\n',
#  '                                                                 rdfs:label "Методы психологического исследования. Математическая психология"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Муниципальное_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Муниципальное_право> rdf:type owl:Class ;\n',
#  '                     rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  '                     rdfs:label "Муниципальное право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Надзор_и_контроль_за_соблюдением_законодательства\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Надзор_и_контроль_за_соблюдением_законодательства> rdf:type owl:Class ;\n',
#  '                                                   rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Трудовое_право> ;\n',
#  '                                                   rdfs:label "Надзор и контроль за соблюдением законодательства"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Назначение_наказания\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Назначение_наказания> rdf:type owl:Class ;\n',
#  '                      rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Уголовное_право> ;\n',
#  '                      rdfs:label "Назначение наказания"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Налоговое_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Налоговое_право> rdf:type owl:Class ;\n',
#  '                 rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Финансовое_право> ;\n',
#  '                 rdfs:label "Налоговое право"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Наследование_по_завещанию\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Наследование_по_завещанию> rdf:type owl:Class ;\n',
#  '                           rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Наследственное_право> ;\n',
#  '                           rdfs:label "Наследование по завещанию"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Наследование_по_закону\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Наследование_по_закону> rdf:type owl:Class ;\n',
#  '                        rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Наследственное_право> ;\n',
#  '                        rdfs:label "Наследование по закону"@ru .\n',
#  '\n',
#  '\n',
#  '###  http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19/Наследственное_право\n',
#  '<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Наследственное_право> rdf:type owl:Class ;\n',
#  '                      rdfs:subClassOf :<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19#Государство_и_право._Юридические_науки> ;\n',
#  ...]

# %%
with open('/home/viktor/dev/grant/onto2wiki-pyclient/fuc_new.ttl', 'w', encoding='utf-8') as f:
     f.write(''.join(new_file))

# %%
def parser_ttl(path):
    parent_children = dict()
    classes = dict()
    with open(path, 'r') as f:
        while line := f.readline():
            pars = re.search(r'(\S+) rdf:type (\S+) ;', line)
            if pars:
                if pars.group(2) != 'owl:Class': raise Exception('Unknown syntaxes')
                # if pars.group(1).startswith(':'):
                #     page = {'title': pars.group(1)[1:]}
                #     while new_line := f.readline().strip():
                #         pars_parent = re.search(r'rdfs:subClassOf :(\S+)', new_line[:-2])
                #         if pars_parent:
                #             pars_parent = pars_parent.group(1).split('#')
                #             if len(pars_parent) == 2:
                #                 pars_parent = pars_parent[1][:-1]
                #             else:
                #                 pars_parent = pars_parent[0]
                #             
                #             if pars_parent not in parent_children:
                #                 parent_children[pars_parent] = [pars.group(1)[1:],]
                #             else:
                #                 parent_children[pars_parent].append(pars.group(1)[1:])
                #         pars_label = re.search(r'rdfs:label "(.+)"@(\S+)', new_line[:-1])
                #         if pars_label:
                #             page.update({f'label@{pars_label.group(2)}': pars_label.group(1)})
                #         if new_line[-1] == '.': break
                #     classes[pars.group(1)[1:]] = page
                # else:
                pars = pars.group(1).split('#')[1][:-1]
                page = {'title': pars}
                while new_line := f.readline().strip():
                    pars_parent = re.search(r'rdfs:subClassOf (\S+)', new_line[:-1])
                    if pars_parent:
                        pars_parent = pars_parent.group(1).split('#')
                        print(pars_parent)
                        if len(pars_parent) == 2:
                            pars_parent = pars_parent[1][:-1]
                        else:
                            pars_parent = pars_parent[0]
                        
                        page.update({'parent': pars_parent})
                        if pars_parent not in parent_children:
                            parent_children[pars_parent] = [pars,]
                        else:
                            parent_children[pars_parent].append(pars)
                    pars_label = re.search(r'rdfs:label "(.+)"@(\S+)', new_line[:-1])
                    if pars_label:
                        page.update({f'label@{pars_label.group(2)}': pars_label.group(1)})
                    if new_line[-1] == '.': break
                classes[pars] = page
    for parent, children in parent_children.items():
        classes[parent].update({'children': children})
    return classes, parent_children

# %%
suka, pch = (parser_ttl('fuc_new.ttl'))
# Out:
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Уголовно-процессуальное_право_(уголовный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Уголовно-процессуальное_право_(уголовный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Гражданско-процессуальное_право_(гражданский_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Гражданско-процессуальное_право_(гражданский_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Уголовно-процессуальное_право_(уголовный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Гражданско-процессуальное_право_(гражданский_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Уголовно-процессуальное_право_(уголовный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Гражданско-процессуальное_право_(гражданский_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Уголовно-процессуальное_право_(уголовный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Гражданско-процессуальное_право_(гражданский_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Уголовно-процессуальное_право_(уголовный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Гражданско-процессуальное_право_(гражданский_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Уголовно-процессуальное_право_(уголовный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Уголовно-процессуальное_право_(уголовный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Гражданско-процессуальное_право_(гражданский_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Уголовно-процессуальное_право_(уголовный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Гражданско-процессуальное_право_(гражданский_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Конституционное_(государственное)_право>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Гражданско-процессуальное_право_(гражданский_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Уголовно-процессуальное_право_(уголовный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Гражданско-процессуальное_право_(гражданский_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']
# ['<http://www.semanticweb.org/григорий/ontologies/2024/10/untitled-ontology-19', 'Арбитражно-процессуальное_право_(арбитражный_процесс)>']

# %%
from Onto2WikiClient import find_roots

# %%
find_roots(suka)
# Out:
# ['Административное_производство_(административный_процесс)',
#  'Арбитражно-процессуальное_право_(арбитражный_процесс)',
#  'Государственное_управление_в_области_использования,_охраны,_защиты_лесного_фонда_и_воспроизводства_лесов',
#  'Гражданско-процессуальное_право_(гражданский_процесс)',
#  'Имущественные_и_неимущественные_права_авторов_открытий,_изобретений_и_рационализаторских_предложений_и_их_охрана',
#  'Конституционное_(государственное)_право',
#  'Криминалистическая_тактика_(тактика_расследования_преступлений)',
#  'Криминалистическая_техника_(техника_расследования_преступления)',
#  'Льготы_нетрудоспособным,_престарелым,_семьям,_имеющим_детей',
#  'Международное_и_национальное_право_(вопросы_взаимодействия)',
#  'Международные_конгрессы,_конференции,_совещания',
#  'Научные_общества,_конгрессы,_конференции,_симпозиумы_юристов',
#  'Научные_общества,_съезды,_конгрессы,_конференции,_симпозиумы_по_психологии',
#  'Опека,_попечительство_и_патронат',
#  'Органы,_осуществляющие_оперативно-розыскную_деятельность',
#  'Охрана_секретов_производства_(ноу-хау)',
#  'Правово__режим_информации,_информационных_систем_и_сетей',
#  'Правовое_положение_крестьянских_(фермерских)__хозяйств',
#  'Правовое_регулирование_лесопользования,_воспроизводства_лесов,_лесоразведения,_охраны_и_защиты_лесов',
#  'Причины_и_условия,_порождающие_преступления',
#  'Происхождение,_сущность,_исторические_типы_и_функции_государства_и_права',
#  'Сравнительная_психология._Зоопсихология,_этология',
#  'Субъекты_гражданских_прав_(лица)',
#  'Территориальные_(региональные)_органы_исполнительной_власти',
#  'Уголовно-процессуальное_право_(уголовный_процесс)',
#  'Авиационная_и_космическая_психология',
#  'Авторские_договоры',
#  'Авторское_право',
#  'Авторское_право_и_смежные_права',
#  'Авторское_право_и_смежные_права_в_отдельных_странах',
#  'Аграрное_право',
#  'Аграрное_право_отдельных_стран',
#  'Адвокатура',
#  'Административно-правовая_ответственность',
#  'Административное_право',
#  'Административное_право_отдельных_стран',
#  'Антимонопольное_законодательство',
#  'Банковское_законодательство',
#  'Банкротство',
#  'Биологическое_и_социальное_в_психике',
#  'Брак._Семья',
#  'Бюджетное_право',
#  'Виды_преступности',
#  'Виктимология',
#  'Внешняя_политика_и_дипломатия',
#  'Внутригосударственные_органы_внешних_сношений',
#  'Водное_право',
#  'Водное_право_отдельных_стран',
#  'Военная_психология',
#  'Воздухоохранное_право',
#  'Вопросы_трудовых_правоотношений',
#  'Всеобщая_история_государства_и_права',
#  'Всеобщая_история_политических_и_правовых_учений',
#  'Гарантии_и_компенсации',
#  'Государственная_служба',
#  'Государственное_регулирование_и_управление_в_административно-политической_сфере',
#  'Государственное_регулирование_и_управление_в_социально-культурной_сфере',
#  'Государственное_регулирование_и_управление_в_сфере_экономики',
#  'Государственное_регулирование_отношений_недропользования',
#  'Государственное_регулирование_предпринимательской_деятельности',
#  'Государственное_регулирование_сельского_хозяйства',
#  'Государственное_социальное_страхование',
#  'Государственное_управление_в_области_использования_и_охраны_водных_объектов',
#  'Государственное_управление_в_сфере_обороны',
#  'Государство_и_право._Юридические_науки',
#  'Государство_и_право_отдельных_стран',
#  'Гражданско-правовая_ответственность',
#  'Гражданское_право',
#  'Гражданское_право_отдельных_стран',
#  'Детская_и_юношеская_психология',
#  'Деятельность_контрольных_органов',
#  'Дифференциальная_психология',
#  'Другие_виды_вещных_прав',
#  'Другие_виды_прикладной_психологии',
#  'Забастовки._Локауты',
#  'Законодательство_о_животном_мире',
#  'Законодательство_о_недрах',
#  'Законодательство_о_недрах_отдельных_стран',
#  'Заработная_плата',
#  'Зарубежные_органы_внешних_сношений',
#  'Защита_коммерческой_тайны',
#  'Земельное_право',
#  'Земельное_право_отдельных_стран',
#  'Землеустройство_и_землеустроительный_процесс._Земельный_кадастр',
#  'Имущественные_права_авторов_и_исполнителей',
#  'Инженерная_психология',
#  'Информационная_деятельность_в_области_психологии',
#  'Информационная_деятельность_в_юридических_науках._Правовая_информация',
#  'Информационное_право',
#  'Использование_произведений_без_согласия_авторов_и_исполнителей',
#  'Историческая_психология',
#  'История_государства_и_права',
#  'История_государства_и_права_отдельных_стран',
#  'История_международного_права',
#  'История_политических_и_правовых_учений',
#  'История_политических_и_правовых_учений_отдельных_стран',
#  'История_психологии._Персоналия',
#  'История_юридической_науки._Персоналия',
#  'Источники_международного_права',
#  'Источники_права',
#  'Кадры_в_области_права_и_юридических_наук',
#  'Кадры_психологов',
#  'Коллективный_договор',
#  'Криминалистика',
#  'Криминалистика_в_отдельных_странах',
#  'Криминалистическая_экспертиза',
#  'Криминология',
#  'Криминология_в_отдельных_странах',
#  'Лесное_право',
#  'Лесное_право_отдельных_стран',
#  'Личность_преступника',
#  'Личные_неимущественные_права_авторов_и_исполнителей',
#  'Логика_права',
#  'Льготы_ветеранам_войны',
#  'Льготы_для_совмещающих_работу_с_обучением',
#  'Массовые_формы_внеколлективного_поведения',
#  'Материальная_ответственность_рабочих_и_служащих',
#  'Материально-бытовое_обслуживание_нетрудоспособных',
#  'Медицинская_психология',
#  'Международное_воздушное_право',
#  'Международное_гуманитарное_право._Право_вооруженных_конфликтов',
#  'Международное_космическое_право',
#  'Международное_морское_право',
#  'Международное_право',
#  'Международное_право_в_практике_отдельных_государств',
#  'Международное_право_окружающей_среды',
#  'Международное_сотрудничество_в_области_права',
#  'Международное_сотрудничество_в_области_психологии',
#  'Международное_сотрудничество_по_специальным_вопросам',
#  'Международное_уголовное_право',
#  'Международное_частное_право',
#  'Международное_частное_право_в_практике_отдельных_стран',
#  'Международное_экономическое_право',
#  'Международный_гражданский_процесс',
#  'Места_лишения_свободы',
#  'Методика_расследования_отдельных_видов_преступлений',
#  'Методология_и_методы_исследования_юридической_науки',
#  'Методы_исследования_и_моделирования_в_области_психологии._Математические_и_кибернетические_методы',
#  'Методы_психологического_исследования._Математическая_психология',
#  'Муниципальное_право',
#  'Надзор_и_контроль_за_соблюдением_законодательства',
#  'Назначение_наказания',
#  'Налоговое_право',
#  'Наследование_по_завещанию',
#  'Наследование_по_закону',
#  'Наследственное_право',
#  'Наследственное_право_в_международном_частном_праве',
#  'Наследственное_право_отдельных_стран',
#  'Нормирование_труда',
#  'Нотариат',
#  'Общая_психология',
#  'Общественное_мнение_и_право._Опинионика',
#  'Общественные_фонды_содержания_и_обслуживания_детей_в_детских_учреждениях',
#  'Общие_вопросы',
#  'Общие_вопросы_авторского_и_смежных_прав',
#  'Общие_вопросы_аграрного_права',
#  'Общие_вопросы_административного_права',
#  'Общие_вопросы_водного_права',
#  'Общие_вопросы_воздухоохранного_права',
#  'Общие_вопросы_гражданского_права',
#  'Общие_вопросы_законодательства_о_животных',
#  'Общие_вопросы_законодательства_о_недрах',
#  'Общие_вопросы_законодательства_о_правоохранительных_органах',
#  'Общие_вопросы_законодательства_о_социальном_обеспечении',
#  'Общие_вопросы_земельного_права',
#  'Общие_вопросы_информационного_права',
#  'Общие_вопросы_истории_государства_и_права',
#  'Общие_вопросы_истории_политических_и_правовых_учений',
#  'Общие_вопросы_криминалистики',
#  'Общие_вопросы_криминологии',
#  'Общие_вопросы_лесного_права',
#  'Общие_вопросы_международного_права',
#  'Общие_вопросы_международного_частного_права',
#  'Общие_вопросы_наследственного_права',
#  'Общие_вопросы_патентного_права',
#  'Общие_вопросы_предпринимательского_права',
#  'Общие_вопросы_психологии',
#  'Общие_вопросы_семейного_права',
#  'Общие_вопросы_судебной_статистики',
#  'Общие_вопросы_теории_государства_и_права',
#  'Общие_вопросы_трудового_права',
#  'Общие_вопросы_уголовного_права',
#  'Общие_вопросы_финансового_права',
#  'Общие_вопросы_экологического_права',
#  'Общие_положения_муниципального_права',
#  'Объекты_авторского_и_смежных_прав',
#  'Объекты_гражданских_прав',
#  'Объекты_правовой_охраны_природы',
#  'Объекты_промышленной_собственности._Условия_патентоспособности',
#  'Обязательственное_право',
#  'Обязательственное_право_в_международном_частном_праве',
#  'Организация_научно-исследовательской_работы_в_области_психологии',
#  'Организация_научно-исследовательской_работы_и_общественно-политической_деятельности_юристов',
#  'Организация_труда._Повышение_квалификации',
#  'Органы_административной_юстиции',
#  'Органы_исполнительной_власти',
#  'Органы_местного_самоуправления',
#  'Освобождение_от_уголовной_ответственности_и_наказания',
#  'Основания_возникновения_гражданских_прав_и_обязанностей',
#  'Особые_состояния_и_явления_психики',
#  'Осуществление_и_защита_гражданских_прав',
#  'Ответственность_в_авторском_праве',
#  'Ответственность_в_аграрном_праве',
#  'Ответственность_в_земельном_праве',
#  'Ответственность_в_патентном_праве_и_праве_промышленной_собственности',
#  'Ответственность_в_предпринимательском_праве._Споры_в_предпринимательской_деятельности_и_порядок_их_разрешения',
#  'Ответственность_в_семейном_праве',
#  'Ответственность_в_системе_муниципального_права',
#  'Ответственность_за_нарушение_водного_законодательства',
#  'Ответственность_за_нарушение_воздухоохранного_законодательства',
#  'Ответственность_за_нарушение_законодательства_о_животном_мире',
#  'Ответственность_за_нарушение_законодательства_о_наследовании',
#  'Ответственность_за_нарушение_законодательства_о_недрах',
#  'Ответственность_за_нарушение_законодательства_по_социальному_обеспечению',
#  'Ответственность_за_нарушение_лесного_законодательства',
#  'Ответственность_за_нарушение_финансового_законодательства',
#  'Отдельные_виды_преступлений',
#  'Отклоняющееся_поведение',
#  'Открытие_наследства_и_меры_его_охраны',
#  'Отраслевые_и_межотраслевые_органы_исполнительной_власти',
#  'Охрана_авторских_прав',
#  'Охрана_водных_объектов',
#  'Охрана_земли',
#  'Охрана_недр',
#  'Охрана_труда',
#  'Патентное_право',
#  'Патентное_право._Право_промышленной_собственности',
#  'Патентное_право_и_право_промышленной_собственности_отдельных_стран',
#  'Патенты_и_их_правовая_защита',
#  'Патопсихология',
#  'Педагогическая_психология',
#  'Пенитенциарные_системы._Режим_содержания_заключенных._Управление_местами_лишения_свободы',
#  'Пенсии',
#  'Переход_наследства_к_государству',
#  'Планирование_и_прогнозирование_в_праве',
#  'Плата_при_пользовании_недрами',
#  'Платежи_за_пользование_лесным_фондом',
#  'Платность_водопользования',
#  'Понятие_наследства',
#  'Пособия',
#  'Права_патентообладателей',
#  'Права_человека',
#  'Право_водопользования._Целевое_использование_водных_объектов',
#  'Право_землепользования_и_его_виды',
#  'Право_и_естественные_науки',
#  'Право_и_научно-технический_прогресс',
#  'Право_и_политика',
#  'Право_международной_безопасности',
#  'Право_международных_договоров',
#  'Право_международных_организаций',
#  'Право_мирного_разрешения_споров',
#  'Право_на_изобретение',
#  'Право_на_информацию',
#  'Право_на_научное_открытие',
#  'Право_на_научное_открытие_в_патентном_праве',
#  'Право_на_рационализаторское_предложение',
#  'Право_пользования_недрами',
#  'Право_собственности',
#  'Право_собственности_в_международном_частном_праве',
#  'Право_собственности_и_другие_права_на_водные_объекты',
#  'Право_собственности_на_землю',
#  'Право_собственности_на_лесной_фонд',
#  'Право_собственности_на_недра',
#  'Право_собственности_на_объекты_животного_мира',
#  'Право_собственности_на_природные_ресурсы',
#  'Право_социального_обеспечения',
#  'Право_социального_обеспечения_в_отдельных_странах',
#  'Правовая_охрана_атмосферного_воздуха',
#  'Правовая_охрана_объектов_животного_мира',
#  'Правовая_работа_и_правовое_обслуживание',
#  'Правовое_оформление_права_наследования',
#  'Правовое_положение_сельскохозяйственных_организаций',
#  'Правовое_регулирование_ведения_государственных_кадастров_природных_ресурсов_и_объектов',
#  'Правовое_регулирование_государственного_управления_земельными_ресурсами',
#  'Правовое_регулирование_государственного_управления_природопользованием_и_охраной_окружающей_среды',
#  'Правовое_регулирование_государственных_доходов._Налоговое_законодательство',
#  'Правовое_регулирование_государственных_расходов_и_бюджетного_финансирования',
#  'Правовое_регулирование_информационной_безопасности',
#  'Правовое_регулирование_использования_объектов_животного_мира',
#  'Правовое_регулирование_личного_подсобного_хозяйства_граждан',
#  'Правовое_регулирование_международного_обмена_информацией_и_использования_глобальных_информационных_сетей',
#  'Правовое_регулирование_отдельных_отраслей_экономики',
#  'Правовое_регулирование_оценки_воздействия_на_окружающую_среду_и_экологической_экспертизы',
#  'Правовое_регулирование_сельскохозяйственной_кооперации',
#  'Правовое_регулирование_средств_массовой_информации',
#  'Правовое_регулирование_цен__и_тарифов',
#  'Правовое_регулирование_экологического_воспитания_и_образования',
#  'Правовое_регулирование_экологического_лицензирования',
#  'Правовое_регулирование_экологического_нормирования',
#  'Правовое_регулирование_экологической_сертификации',
#  'Правовое_регулирование_экономического_механизма_природопользования_и_охраны_окружающей_среды',
#  'Правовой_режим_земель_водного_фонда',
#  'Правовой_режим_земель_лесного_фонда',
#  'Правовой_режим_земель_несельскохозяйственного_назначения',
#  'Правовой_режим_земель_сельскохозяйственного_назначения',
#  'Правовой_режим_информационных_ресурсов',
#  'Правовой_режим_населенных_пунктов',
#  'Правовой_режим_особо_охраняемых_природных_территорий',
#  'Правовой_режим_экологически_неблагополучных_территорий',
#  'Правовые_аспекты_ирригации_и_мелиорации',
#  'Правовые_основы_инвестиционной_деятельности',
#  'Правовые_основы_расчетов_и_денежного_обращения._Основы_валютного_законодательства',
#  'Правовые_проблемы_охраны_окружающей_среды._Экологическое_право',
#  'Правовые_формы_предпринимательской_деятельности',
#  'Правонарушения_в_области_информатики._Ответственность_в_информационном_праве',
#  'Правоохранительные_органы',
#  'Правоохранительные_органы_отдельных_стран',
#  'Практическая_психология',
#  'Предметы_ведения_и_полномочия_органов_исполнительной_власти',
#  'Предпринимательское_право',
#  'Предпринимательское_право_отдельных_стран',
#  'Представительство',
#  'Представительство_в_международном_частном_праве',
#  'Предупреждение_преступлений',
#  'Преподавание_юридических_наук',
#  'Преступность_и_явления_социальной_патологии',
#  'Прикладная_психология',
#  'Принципы_международного_права',
#  'Принятие_наследства_и_отказ_от_наследства',
#  'Прогнозирование_преступности',
#  'Прокуратура',
#  'Пропаганда_правовых_знаний',
#  'Процессы_социализации',
#  'Психика_и_сознание',
#  'Психические_процессы_и_состояния',
#  'Психология',
#  'Психология_деятельности_и_поведения._Психология_мотивации',
#  'Психология_зрелости',
#  'Психология_классов_и_крупных_социальных_общностей',
#  'Психология_личности',
#  'Психология_малых_групп_и_коллективов',
#  'Психология_межличностных_отношений',
#  'Психология_общения._Процессы_коммуникации',
#  'Психология_пола',
#  'Психология_права',
#  'Психология_развития._Возрастная_психология._Сравнительная_психология',
#  'Психология_семьи_и_быта',
#  'Психология_спорта',
#  'Психология_старения',
#  'Психология_творчества',
#  'Психология_труда',
#  'Психология_управления',
#  'Психология_чтения_и_библиотечной_работы',
#  'Психофизиология',
#  'Рабочее_время_и_время_отдыха',
#  'Развитие_психики',
#  'Родство_по_семейному_праву',
#  'Розыск',
#  'Роль_профессиональных_союзов_в_трудовых_правоотношениях._Участие_рабочих_и_служащих_в_управлении_производством',
#  'Сделки',
#  'Семейное_право',
#  'Семейное_право_в_международном_частном_праве',
#  'Семейное_право_отдельных_стран',
#  'Служащие_мест_лишения_свободы',
#  'Современное_состояние_и_перспективы_развития_психологии',
#  'Современное_состояние_и_перспективы_развития_юридической_науки',
#  'Состояние_преступности',
#  'Социальная_психология',
#  'Социальная_психология_личности._Личность_и_общество._Психология_жизненной_сферы',
#  'Социальные_нормы_и_ценности',
#  'Социология_права',
#  'Социология_преступности',
#  'Ступени_исполнения_приговора',
#  'Субъективные_гражданские_права',
#  'Субъекты_авторского_и_смежных_прав',
#  'Субъекты_международного_права',
#  'Субъекты_международного_частного_права',
#  'Субъекты_предпринимательского_права',
#  'Суд._Судоустройство',
#  'Судебная_статистика',
#  'Судебная_статистика_отдельных_стран',
#  'Судебная_статистика_по_гражданским_делам',
#  'Судебная_статистика_по_уголовным_делам',
#  'Теория_государства',
#  'Теория_государства_и_права',
#  'Теория_международного_права',
#  'Теория_права',
#  'Терминология._Справочная_литература._Учебная_литература',
#  'Территория_в_международном_праве',
#  'Труд_женщин',
#  'Труд_молодежи',
#  'Трудовая_дисциплина',
#  'Трудовое_право',
#  'Трудовое_право_отдельных_стран',
#  'Трудовой_договор',
#  'Трудовой_стаж',
#  'Трудовые_ресурсы._Трудоустройство',
#  'Трудовые_споры',
#  'Уголовно-исполнительное_право._Пенитенциария',
#  'Уголовное_право',
#  'Уголовное_право_отдельных_стран',
#  'Унифицированные_нормы_в_международном_частном_праве',
#  'Управление_и_организация_в_области_социального_обеспечения',
#  'Управление_использованием_и_охраной_животного_мира',
#  'Управление_охраной_атмосферного_воздуха',
#  'Усыновление',
#  'Участие_общественности_в_деятельности_правоохранительных_органов',
#  'Учение_о_наказании',
#  'Учение_о_преступлении',
#  'Учении_о_коллизии_законов',
#  'Философские_вопросы_и_методология_психологии',
#  'Философския_права',
#  'Финансовая_деятельность_государства._Финансовый_контроль',
#  'Финансово-экономическая_основа_местного_самоуправления',
#  'Финансовое_право',
#  'Финансовое_право_отдельных_стран',
#  'Фонды_социального_обеспечения_и_социального_страхования',
#  'Формы_и_методы_борьбы_с_преступностью_и_предупреждения_преступлений',
#  'Формы_и_методы_управления',
#  'Формы_прямого_волеизъявления_граждан_и_другие_формы_осуществления_местного_самоуправления',
#  'Экологические_права_человека_и_гражданина',
#  'Экологический_аудит._Экологический_мониторинг._Экологический_контроль',
#  'Экологическое_право_в_отдельных_странах',
#  'Экономическая_психология',
#  'Этнопсихология',
#  'Юридическая_ответственность_за_экологические_правонарушения',
#  'Юридическая_психология',
#  'Юридическая_терминология']

# %%
new_classes = suka.keys()
for class_ in new_classes:
    if class_ not in classes:
        print(class_)
print(len(new_classes), len(classes))
# Out:
# 464 464

# %%
pprint(suka['Государство_и_право._Юридические_науки'])
# pprint(pch)
# Out:
# {'children': ['Арбитражно-процессуальное_право_(арбитражный_процесс)',
#               'Гражданско-процессуальное_право_(гражданский_процесс)',
#               'Конституционное_(государственное)_право',
#               'Уголовно-процессуальное_право_(уголовный_процесс)',
#               'Авторское_право_и_смежные_права',
#               'Аграрное_право',
#               'Административное_право',
#               'Водное_право',
#               'Воздухоохранное_право',
#               'Государство_и_право_отдельных_стран',
#               'Гражданское_право',
#               'Законодательство_о_животном_мире',
#               'Законодательство_о_недрах',
#               'Земельное_право',
#               'Информационное_право',
#               'История_государства_и_права',
#               'История_политических_и_правовых_учений',
#               'Криминалистика',
#               'Криминология',
#               'Лесное_право',
#               'Международное_право',
#               'Международное_частное_право',
#               'Муниципальное_право',
#               'Наследственное_право',
#               'Общие_вопросы',
#               'Патентное_право._Право_промышленной_собственности',
#               'Право_социального_обеспечения',
#               'Правовые_проблемы_охраны_окружающей_среды._Экологическое_право',
#               'Правоохранительные_органы',
#               'Предпринимательское_право',
#               'Семейное_право',
#               'Судебная_статистика',
#               'Теория_государства_и_права',
#               'Трудовое_право',
#               'Уголовно-исполнительное_право._Пенитенциария',
#               'Уголовное_право',
#               'Финансовое_право'],
#  'label@ru': 'Государство и право. Юридические науки',
#  'title': 'Государство_и_право._Юридические_науки'}
